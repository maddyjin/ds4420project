# %%
# Exploratory Data Analysis for a neural network approach

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read in cleaned csv
df = pd.read_csv("../data/bills_cleaned.csv")
df.head()
# Out:
#   Legislation Number                                                URL  \
# 0          H.R. 7933  https://www.congress.gov/bill/119th-congress/h...
# 1          H.R. 7932  https://www.congress.gov/bill/119th-congress/h...
# 2          H.R. 7931  https://www.congress.gov/bill/119th-congress/h...
# 3          H.R. 7930  https://www.congress.gov/bill/119th-congress/h...
# 4          H.R. 7929  https://www.congress.gov/bill/119th-congress/h...
#
#                      Congress  \
# 0  119th Congress (2025-2026)
# 1  119th Congress (2025-2026)
# 2  119th Congress (2025-2026)
# 3  119th Congress (2025-2026)
# 4  119th Congress (2025-2026)
#
#                                                Title  \
# 0  To amend title 10, United States Code, to expa...
# 1                       HONOR Gold Star Families Act
# 2  To amend the Employee Retirement Income Securi...
# 3  To amend title 18, United States Code, to incr...
# 4  To direct the Secretary of Transportation to i...
#
# ...

# %%
df["Date of Introduction"] = pd.to_datetime(df["Date of Introduction"], errors="coerce")
df["Latest Action Date"] = pd.to_datetime(df["Latest Action Date"], errors="coerce")
